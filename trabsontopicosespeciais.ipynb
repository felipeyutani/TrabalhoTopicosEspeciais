# %% [markdown]
# <a href="https://colab.research.google.com/github/felipeyutani/TrabalhoTopicosEspeciais/blob/main/trabsontopicosespeciais.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Imports

# %%
import numpy as np
import pandas as pd
import cv2 as cv
from google.colab.patches import cv2_imshow
from skimage import io
from PIL import Image 
import matplotlib.pylab as plt
import scipy

# %% [markdown]
# # 1. Desenvolva um código que lhe permita abrir uma imagem RGB ou BGR de sua preferência, utilizando a interface python do OpenCV. Logo depois, converta a imagem para escala de cinza e exiba as duas imagens lado a lado na tela.

# %%
imgs = ["imagem.png"]

for img in imgs:
  image = io.imread(img)
  image_rgb = cv2.cvtColor(image, cv.COLOR_BGR2RGB)

  print('\n')

grayImg = cv2.cvtColor(image_rgb, cv2.COLOR_BGR2GRAY)
# juncao = cv2.hconcat((image_rgb, grayImg))
# cv2_imshow(juncao)
cv2_imshow(image_rgb)
cv2_imshow(grayImg)
# Out:
# <PIL.Image.Image image mode=RGB size=600x568 at 0x7F476FBD79D0>
# <PIL.Image.Image image mode=L size=600x568 at 0x7F4773C13B10>

# %% [markdown]
# # 2. Utilizando o código fonte das nossas aulas como base, carregue uma imagem contendo pelo menos uma face (pode ser a imagem carregada no item 1), depois carregue o modelo de detecção de faces utilizado nas nossas aulas anteriores. Construa um código de detecção de faces, encontre a caixa envolvente da face na imagem. Pinte o retângulo ao redor da face encontrada e exiba a imagem pintada na tela.

# %%
faceimg = ["face.jpg"]

for face in faceimg:
  image = io.imread(face)
  image_rgb = cv2.cvtColor(image, cv.COLOR_BGR2RGB)

  cv2_imshow(image_rgb)

face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')

for (x,y,w,h) in faces:
     cv2.rectangle(image_rgb,(x,y),(x+w,y+h),(255,0,0),2)

cv2_imshow(image_rgb)
# Out:
# <PIL.Image.Image image mode=RGB size=440x440 at 0x7F4774535450>
# <PIL.Image.Image image mode=RGB size=440x440 at 0x7F4774535590>

# %% [markdown]
# # 3. Carregue uma imagem que contenha uma página de texto de um documento digitalizado de sua preferência. Uma vez carregada a imagem, utilize o OCR com o qual trabalhamos na nossa última aula (Tesseract), reconheça o texto, e imprima o texto reconhecido na tela.

# %%
import pytesseract
import shutil
import os
import random
try:
 from PIL import Image
except ImportError:
 import Image

# %%
imgs = ["texto.jpg"]

for img in imgs:
  image = io.imread(img)
  image_rgb = cv2.cvtColor(image, cv.COLOR_BGR2RGB)

  cv2_imshow(image_rgb)

  print('\n')

image_path_in_colab= "texto.jpg"

extractedInformation = pytesseract.image_to_string(Image.open(image_path_in_colab))
print(extractedInformation)
# Out:
# <PIL.Image.Image image mode=RGB size=1080x1080 at 0x7F476FACC8D0>
# Nunca duvide do
# seu potencial,
# viu? Vocé é
# maravilhosa,
# saiba que eu te
# admiro demais.
#
# S% mensagenscomamor
